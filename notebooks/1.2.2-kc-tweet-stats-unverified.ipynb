# %%
import twint
import nest_asyncio
from lib import bittwint
import pandas as pd
import matplotlib.pyplot as plt

nest_asyncio.apply()

# %%
df = bittwint.scrape_twitter(
    "bitcoin", 
    10000, 
    "2021-05-01",
    until="2021-06-01",
    verified=False, 
    output="../data/raw/bitcoin_unverified_tweets_9.csv"
)

df.head()
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
# CRITICAL:root:twint.run:Twint:Feed:noData'globalObjects'
# sleeping for 1.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noData'globalObjects'
# sleeping for 1.0 secs
#                     id      conversation_id    created_at  \
# 0  1388644390676176898  1388644390676176898  1.619914e+12
# 1  1388644328399048704  1388598075178950658  1.619914e+12
# 2  1388644322682224642  1388644322682224642  1.619914e+12
# 3  1388644320585175042  1388644320585175042  1.619914e+12
# 4  1388644307507286018  1388616157704331265  1.619914e+12
#
#                   date timezone place  \
# 0  2021-05-01 19:59:57    -0500
# ...

# %%
# fix, ax = plt.subplots(figsize=(10, 7))
# ax.bar(date_count['date'], date_count['id'])
# plt.show()

# %%
df
# Out:
#                          id      conversation_id    created_at  \
# 0       1388644390676176898  1388644390676176898  1.619914e+12
# 1       1388644328399048704  1388598075178950658  1.619914e+12
# 2       1388644322682224642  1388644322682224642  1.619914e+12
# 3       1388644320585175042  1388644320585175042  1.619914e+12
# 4       1388644307507286018  1388616157704331265  1.619914e+12
# ...                     ...                  ...           ...
# 293602  1399798658468622337  1399798658468622337  1.622573e+12
# 293603  1399798647869652993  1399690777312247808  1.622573e+12
# 293604  1399798644556111872  1399798644556111872  1.622573e+12
# 293605  1399798639078281223  1399798639078281223  1.622573e+12
# 293606  1399798638054760449  1399798638054760449  1.622573e+12
#
#                        date timezone place  \
# 0       2021-05-01 19:59:57    -0500
# 1       2021-05-01 19:59:42    -0500
# 2       2021-05-01 19:59:40    -0500
# 3       2021-05-01 19:59:40    -0500
# ...
