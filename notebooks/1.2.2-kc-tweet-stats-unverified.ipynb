# %%
import twint
import nest_asyncio
from lib import bittwint
import pandas as pd
import matplotlib.pyplot as plt

nest_asyncio.apply()

# %%
df = bittwint.scrape_twitter(
    "bitcoin", 
    10000, 
    "2021-08-01",
    until="2021-09-01",
    verified=False, 
    output="../data/raw/bitcoin_unverified_tweets_6.csv"
)

df.head()
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#                     id      conversation_id    created_at  \
# 0  1421984085187072000  1421982610373349377  1.627862e+12
# 1  1421984047757209605  1421984047757209605  1.627862e+12
# 2  1421984003947745283  1421982277811253249  1.627862e+12
# 3  1421984000969748482  1421861313207169025  1.627862e+12
# 4  1421984000592252938  1421828424092590086  1.627862e+12
#
#                   date timezone place  \
# 0  2021-08-01 19:59:59    -0500
# 1  2021-08-01 19:59:50    -0500
# 2  2021-08-01 19:59:40    -0500
# 3  2021-08-01 19:59:39    -0500
# 4  2021-08-01 19:59:39    -0500
#
#                                                tweet language hashtags  \
# 0  @APompliano CashApp fees for buying/selling Bi...       en       []
# 1             You can still get $39950 for a bitcoin       en       []
# 2                            @llenas_miguel Bitcoin.       en       []
# 3  @FiftySatFinance I’ve been buying Bitcoin with...       en       []
# 4  @LeeSmit97097126 @ShibaInfluencer They have se...       en       []
#
#   cashtags  ...  geo source user_rt_id user_rt  retweet_id  \
# 0       []  ...
# 1       []  ...
# 2       []  ...
# 3       []  ...
# 4       []  ...
#
#                                             reply_to retweet_date translate  \
# 0  [{'screen_name': 'APompliano', 'name': 'Pomp 🌪...
# 1                                                 []
# 2  [{'screen_name': 'llenas_miguel', 'name': 'Mig...
# 3  [{'screen_name': 'FiftySatFinance', 'name': 'F...
# 4  [{'screen_name': 'LeeSmit97097126', 'name': 'L...
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]

# %%
# fix, ax = plt.subplots(figsize=(10, 7))
# ax.bar(date_count['date'], date_count['id'])
# plt.show()

# %%
df
# Out:
#                          id      conversation_id    created_at  \
# 0       1421984085187072000  1421982610373349377  1.627862e+12
# 1       1421984047757209605  1421984047757209605  1.627862e+12
# 2       1421984003947745283  1421982277811253249  1.627862e+12
# 3       1421984000969748482  1421861313207169025  1.627862e+12
# 4       1421984000592252938  1421828424092590086  1.627862e+12
# ...                     ...                  ...           ...
# 313591  1433128457102372865  1433128457102372865  1.630519e+12
# 313592  1433128448394936324  1433128448394936324  1.630519e+12
# 313593  1433128445433765889  1433073757124452359  1.630519e+12
# 313594  1433128434549547014  1433128434549547014  1.630519e+12
# 313595  1433128433475747845  1433128433475747845  1.630519e+12
#
#                        date timezone place  \
# 0       2021-08-01 19:59:59    -0500
# 1       2021-08-01 19:59:50    -0500
# 2       2021-08-01 19:59:40    -0500
# 3       2021-08-01 19:59:39    -0500
# 4       2021-08-01 19:59:39    -0500
# ...                     ...      ...   ...
# 313591  2021-09-01 14:03:45    -0500
# 313592  2021-09-01 14:03:42    -0500
# 313593  2021-09-01 14:03:42    -0500
# 313594  2021-09-01 14:03:39    -0500
# 313595  2021-09-01 14:03:39    -0500
#
#                                                     tweet language  \
# 0       @APompliano CashApp fees for buying/selling Bi...       en
# 1                  You can still get $39950 for a bitcoin       en
# 2                                 @llenas_miguel Bitcoin.       en
# 3       @FiftySatFinance I’ve been buying Bitcoin with...       en
# 4       @LeeSmit97097126 @ShibaInfluencer They have se...       en
# ...                                                   ...      ...
# 313591  Crypto utilization &amp; adoption continues, a...       en
# 313592  Welcome to the #getUmbrel tribe. Full #Bitcoin...       en
# 313593  @Bilthon @alpacasw @Bitcoinfuture9 @AaronvanW ...       en
# 313594  Our reality is full of paradoxes. Chaos and or...       en
# 313595  9- and 14-year-old Bitcoin, ETH, RVN Miners ‘M...       en
#
#                          hashtags cashtags  ...  geo source user_rt_id  \
# 0                              []       []  ...
# 1                              []       []  ...
# 2                              []       []  ...
# 3                              []       []  ...
# 4                              []       []  ...
# ...                           ...      ...  ...  ...    ...        ...
# 313591                         []       []  ...
# 313592  [getumbrel, bitcoin, btc]       []  ...
# 313593                         []       []  ...
# 313594                  [bitcoin]       []  ...
# 313595                         []       []  ...
#
#        user_rt  retweet_id                                           reply_to  \
# 0                           [{'screen_name': 'APompliano', 'name': 'Pomp 🌪...
# 1                                                                          []
# 2                           [{'screen_name': 'llenas_miguel', 'name': 'Mig...
# 3                           [{'screen_name': 'FiftySatFinance', 'name': 'F...
# 4                           [{'screen_name': 'LeeSmit97097126', 'name': 'L...
# ...        ...         ...                                                ...
# 313591                                                                     []
# 313592                                                                     []
# 313593                      [{'screen_name': 'Bilthon', 'name': 'Bilthon [...
# 313594                                                                     []
# 313595                                                                     []
#
#        retweet_date translate trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
# ...             ...       ...       ...         ...
# 313591
# 313592
# 313593
# 313594
# 313595
#
# [313596 rows x 38 columns]
