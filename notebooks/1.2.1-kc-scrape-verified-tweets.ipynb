# %%
# import packages
import twint
import nest_asyncio
from modules import bittwint
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from tqdm.notebook import tqdm

nest_asyncio.apply()

# %%
# scraping function
df = bittwint.scrape_twitter(
    "bitcoin", 
    100000, 
    "2021-01-14", 
    verified=True, 
    output="../data/raw/bitcoin_verified_tweets_5.csv"
)

display(df)

# %%
# get all scraped data
dfs = []

for i in tqdm(range(1, 6)):
    dfs.append(pd.read_csv("../data/raw/bitcoin_verified_tweets_" + str(i) + ".csv", low_memory=False))
    
df = pd.concat(dfs, ignore_index=True)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
# drop duplicates and unused columns
df = df.drop_duplicates(subset=['id'])

df = df.drop(columns=['date', 'time', 'timezone', \
                      'place', 'retweet', 'near', 'geo', 'source', \
                      'user_rt_id', 'user_rt', 'retweet_id', 'retweet_date', \
                      'translate', 'trans_src', 'trans_dest'])

display(df.head())
# Out:
#                     id      conversation_id               created_at  \
# 0  1488663161209249800  1488663161209249800  2022-02-01 18:58:50 EST
# 1  1488662322067357696  1488662322067357696  2022-02-01 18:55:30 EST
# 2  1488661724706316291  1488661724706316291  2022-02-01 18:53:07 EST
# 3  1488661503305822208  1488573276775333889  2022-02-01 18:52:15 EST
# 4  1488661430886977536  1488661430886977536  2022-02-01 18:51:57 EST
#
#                user_id         username         name  \
# 0  1248996730940448774  ratemyskyperoom   Room Rater
# 1             32318850       calvinayre  Calvin Ayre
# 2             14115083         jcastros      JCS 🇨🇴⚡
# 3             14110443           muneeb   muneeb.btc
# 4   993530753014054912     decryptmedia      Decrypt
#
#                                                tweet language  \
# 0  Good bookshelf setup. Love the white over red....       en
# 1  This was always where it would land and BSV wa...       en
# 2  This is why I am a TCP/IP maxi. #Bitcoin  http...       en
# 3  @davidmarcus We have the same thesis 🤝  Buildi...       en
# 4  Drew Brees to Get Paid in Bitcoin via NYDIG’s ...       en
#
#                                             mentions  \
# 0  [{'screen_name': 'markyusko', 'name': 'mark w....
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                                 urls  ... replies_count  \
# 0                                                 []  ...             3
# 1  ['https://coingeek.com/us-now-defines-bitcoin-...  ...             2
# 2                                                 []  ...             3
# 3                                                 []  ...             1
# 4  ['https://decrypt.co/91807/drew-brees-bitcoin-...  ...             0
#
#    retweets_count  likes_count     hashtags cashtags  \
# 0               1           35           []       []
# 1               5           25           []       []
# 2               9           62  ['bitcoin']       []
# 3               0           47           []       []
# 4               3           14           []       []
#
#                                                 link quote_url video  \
# 0  https://twitter.com/ratemyskyperoom/status/148...       NaN     1
# 1  https://twitter.com/CalvinAyre/status/14886623...       NaN     0
# 2  https://twitter.com/JCastroS/status/1488661724...       NaN     1
# 3  https://twitter.com/muneeb/status/148866150330...       NaN     0
# 4  https://twitter.com/decryptmedia/status/148866...       NaN     1
#
#                                          thumbnail  \
# 0  https://pbs.twimg.com/media/FKjLQV8WYAE0hht.jpg
# 1                                              NaN
# 2  https://pbs.twimg.com/media/FKjJn0HXsAcwGJn.png
# 3                                              NaN
# 4  https://pbs.twimg.com/media/FKjJrpwXsAATX0P.jpg
#
#                                             reply_to
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'screen_name': 'davidmarcus', 'name': 'David...
# 4                                                 []
#
# [5 rows x 21 columns]

# %%
# change data types
df["created_at"] = pd.to_datetime(df["created_at"])

df = df.astype({
    'username': 'string',
    'name': 'string',
    'tweet': 'string',
    'language': 'string',
    'link': 'string',
    'quote_url': 'string',
    'video': 'bool',
    'thumbnail': 'string',
})

display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346456 entries, 0 to 349997
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               346456 non-null  int64
#  1   conversation_id  346456 non-null  int64
#  2   created_at       346456 non-null  datetime64[ns, tzlocal()]
#  3   user_id          346456 non-null  int64
#  4   username         346455 non-null  string
#  5   name             346456 non-null  string
#  6   tweet            346456 non-null  string
#  7   language         346456 non-null  string
#  8   mentions         346456 non-null  object
#  9   urls             346456 non-null  object
#  10  photos           346456 non-null  object
#  11  replies_count    346456 non-null  int64
#  12  retweets_count   346456 non-null  int64
#  13  likes_count      346456 non-null  int64
#  14  hashtags         346456 non-null  object
#  15  cashtags         346456 non-null  object
#  16  link             346456 non-null  string
#  17  quote_url        23752 non-null   string
#  18  video            346456 non-null  bool
#  19  thumbnail        80042 non-null   string
#  20  reply_to         346456 non-null  object
# dtypes: bool(1), datetime64[ns, tzlocal()](1), int64(6), object(6), string(7)
# memory usage: 55.8+ MB
# None

# %%
# filter date from 2020 to 2021
df = df.set_index('created_at').sort_index().loc['2020':'2021'].reset_index()

display(df)
# Out:
#                       created_at                   id      conversation_id  \
# 0      2020-01-01 00:08:28-05:00  1212239143687741440  1212239143687741440
# 1      2020-01-01 00:54:35-05:00  1212250748815208448  1212250748815208448
# 2      2020-01-01 02:00:25-05:00  1212267316789952512  1212267316789952512
# 3      2020-01-01 02:18:48-05:00  1212271940502638593  1212271940502638593
# 4      2020-01-01 02:39:29-05:00  1212277146401402880  1212277146401402880
# ...                          ...                  ...                  ...
# 312516 2021-12-31 23:20:12-05:00  1477132523826147330  1477131257301520385
# 312517 2021-12-31 23:28:45-05:00  1477134677148323841  1477134677148323841
# 312518 2021-12-31 23:38:06-05:00  1477137028894670855  1477132718341337095
# 312519 2021-12-31 23:43:13-05:00  1477138318982725633  1477138318982725633
# 312520 2021-12-31 23:55:44-05:00  1477141468921794560  1477141468921794560
#
#                     user_id        username                    name  \
# 0                  20646945    dumbfoundead        dumbfoundead.eth
# 1                 636023721    neuroecology          Adam J Calhoun
# 2                 631810714    cnbctv18news               CNBC-TV18
# 3                  14654494       excellion              Samson Mow
# 4       1066972567943053312  hindustantimes         Hindustan Times
# ...                     ...             ...                     ...
# 312516            151805556      adeldmeyer                    Adel
# 312517              1414971        jaygould               Jay Gould
# 312518             10446482             nvk  DETERMINISTIC OPTIMISM
# 312519             22594051      staronline                The Star
# 312520             36624001     lordfusitua           Lord Fusitu'a
#
#                                                     tweet language  \
# 0           Bitcoin the worst decision i made this decade       en
# 1       If you ask someone what they'd do if they went...       en
# 2       #bitcoin rally begun in 2013 and it reached a ...       en
# 3       Wishing all #Bitcoin Ultra Enthusiasts a very ...       en
# 4       Breaking down Bitcoin’s 9,000,000% rise in las...       en
# ...                                                   ...      ...
# 312516                      @Bitcoin__art Fair enough 😅😅😅       en
# 312517   Happy New Year #Bitcoin  https://t.co/HdUQNDKUUA       en
# 312518  @rubiconcapital_ Buy bitcoin &amp; chill, defu...       en
# 312519  Bitcoin faces uncertain 2022 after record year...       en
# 312520  You’re a great example to our fellow #Bitcoin ...       en
#
#                                                  mentions  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3       [{'screen_name': 'blockstream', 'name': 'block...
# 4                                                      []
# ...                                                   ...
# 312516                                                 []
# 312517                                                 []
# 312518                                                 []
# 312519                                                 []
# 312520                                                 []
#
#                                                      urls  ... replies_count  \
# 0                                                      []  ...             9
# 1                                                      []  ...             6
# 2       ['https://www.cnbctv18.com/market/currency/bit...  ...             0
# 3                                                      []  ...            10
# 4       ['http://www.hindustantimes.com/tech/breaking-...  ...             0
# ...                                                   ...  ...           ...
# 312516                                                 []  ...             0
# 312517                                                 []  ...             2
# 312518                                                 []  ...             0
# 312519  ['https://www.thestar.com.my/tech/tech-news/20...  ...             0
# 312520                                                 []  ...             0
#
#         retweets_count  likes_count                      hashtags cashtags  \
# 0                   15          409                            []       []
# 1                    0            4                            []       []
# 2                    0            4                   ['bitcoin']       []
# 3                   17          158  ['bitcoin', 'liquidnetwork']       []
# 4                    0            0                            []       []
# ...                ...          ...                           ...      ...
# 312516               0            1                            []       []
# 312517               1           12                   ['bitcoin']       []
# 312518               2            8                            []       []
# 312519               4            7                            []       []
# 312520               3            9                   ['bitcoin']       []
#
#                                                      link  \
# 0       https://twitter.com/dumbfoundead/status/121223...
# 1       https://twitter.com/neuroecology/status/121225...
# 2       https://twitter.com/CNBCTV18News/status/121226...
# 3       https://twitter.com/Excellion/status/121227194...
# 4       https://twitter.com/HindustanTimes/status/1212...
# ...                                                   ...
# 312516  https://twitter.com/AdeldMeyer/status/14771325...
# 312517  https://twitter.com/jaygould/status/1477134677...
# 312518  https://twitter.com/nvk/status/147713702889467...
# 312519  https://twitter.com/staronline/status/14771383...
# 312520  https://twitter.com/LordFusitua/status/1477141...
#
#                                                 quote_url  video  \
# 0                                                    <NA>  False
# 1                                                    <NA>  False
# 2                                                    <NA>  False
# 3                                                    <NA>   True
# 4                                                    <NA>  False
# ...                                                   ...    ...
# 312516                                               <NA>  False
# 312517                                               <NA>   True
# 312518                                               <NA>  False
# 312519                                               <NA>  False
# 312520  https://twitter.com/1ARMPUSHUPKING/status/1477...  False
#
#                                               thumbnail  \
# 0                                                  <NA>
# 1                                                  <NA>
# 2                                                  <NA>
# 3       https://pbs.twimg.com/media/ENLa5toU0AAvhC1.jpg
# 4                                                  <NA>
# ...                                                 ...
# 312516                                             <NA>
# 312517  https://pbs.twimg.com/media/FH_WKPYXsAQRYg_.jpg
# 312518                                             <NA>
# 312519                                             <NA>
# 312520                                             <NA>
#
#                                                  reply_to
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 312516  [{'screen_name': 'Bitcoin__art', 'name': 'bitc...
# 312517                                                 []
# 312518  [{'screen_name': 'rubiconcapital_', 'name': 'K...
# 312519                                                 []
# 312520                                                 []
#
# [312521 rows x 21 columns]

# %%
# export to pickle
df.to_pickle("../data/interim/tweets_verified_2020-2021.pkl")

# %%
# try reading pickle
df_test = pd.read_pickle("../data/interim/tweets_verified_2020-2021.pkl")

display(df_test.dtypes)
display(df_test)
# Out:
# created_at         datetime64[ns, tzlocal()]
# id                                     int64
# conversation_id                        int64
# user_id                                int64
# username                              string
# name                                  string
# tweet                                 string
# language                              string
# mentions                              object
# urls                                  object
# photos                                object
# replies_count                          int64
# retweets_count                         int64
# likes_count                            int64
# hashtags                              object
# cashtags                              object
# link                                  string
# quote_url                             string
# video                                   bool
# thumbnail                             string
# reply_to                              object
# dtype: object
#                       created_at                   id      conversation_id  \
# 0      2020-01-01 00:08:28-05:00  1212239143687741440  1212239143687741440
# 1      2020-01-01 00:54:35-05:00  1212250748815208448  1212250748815208448
# 2      2020-01-01 02:00:25-05:00  1212267316789952512  1212267316789952512
# 3      2020-01-01 02:18:48-05:00  1212271940502638593  1212271940502638593
# 4      2020-01-01 02:39:29-05:00  1212277146401402880  1212277146401402880
# ...                          ...                  ...                  ...
# 312516 2021-12-31 23:20:12-05:00  1477132523826147330  1477131257301520385
# 312517 2021-12-31 23:28:45-05:00  1477134677148323841  1477134677148323841
# 312518 2021-12-31 23:38:06-05:00  1477137028894670855  1477132718341337095
# 312519 2021-12-31 23:43:13-05:00  1477138318982725633  1477138318982725633
# 312520 2021-12-31 23:55:44-05:00  1477141468921794560  1477141468921794560
#
#                     user_id        username                    name  \
# 0                  20646945    dumbfoundead        dumbfoundead.eth
# 1                 636023721    neuroecology          Adam J Calhoun
# 2                 631810714    cnbctv18news               CNBC-TV18
# 3                  14654494       excellion              Samson Mow
# 4       1066972567943053312  hindustantimes         Hindustan Times
# ...                     ...             ...                     ...
# 312516            151805556      adeldmeyer                    Adel
# 312517              1414971        jaygould               Jay Gould
# 312518             10446482             nvk  DETERMINISTIC OPTIMISM
# 312519             22594051      staronline                The Star
# 312520             36624001     lordfusitua           Lord Fusitu'a
#
#                                                     tweet language  \
# 0           Bitcoin the worst decision i made this decade       en
# 1       If you ask someone what they'd do if they went...       en
# 2       #bitcoin rally begun in 2013 and it reached a ...       en
# 3       Wishing all #Bitcoin Ultra Enthusiasts a very ...       en
# 4       Breaking down Bitcoin’s 9,000,000% rise in las...       en
# ...                                                   ...      ...
# 312516                      @Bitcoin__art Fair enough 😅😅😅       en
# 312517   Happy New Year #Bitcoin  https://t.co/HdUQNDKUUA       en
# 312518  @rubiconcapital_ Buy bitcoin &amp; chill, defu...       en
# 312519  Bitcoin faces uncertain 2022 after record year...       en
# 312520  You’re a great example to our fellow #Bitcoin ...       en
#
#                                                  mentions  \
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3       [{'screen_name': 'blockstream', 'name': 'block...
# 4                                                      []
# ...                                                   ...
# 312516                                                 []
# 312517                                                 []
# 312518                                                 []
# 312519                                                 []
# 312520                                                 []
#
#                                                      urls  ... replies_count  \
# 0                                                      []  ...             9
# 1                                                      []  ...             6
# 2       ['https://www.cnbctv18.com/market/currency/bit...  ...             0
# 3                                                      []  ...            10
# 4       ['http://www.hindustantimes.com/tech/breaking-...  ...             0
# ...                                                   ...  ...           ...
# 312516                                                 []  ...             0
# 312517                                                 []  ...             2
# 312518                                                 []  ...             0
# 312519  ['https://www.thestar.com.my/tech/tech-news/20...  ...             0
# 312520                                                 []  ...             0
#
#         retweets_count  likes_count                      hashtags cashtags  \
# 0                   15          409                            []       []
# 1                    0            4                            []       []
# 2                    0            4                   ['bitcoin']       []
# 3                   17          158  ['bitcoin', 'liquidnetwork']       []
# 4                    0            0                            []       []
# ...                ...          ...                           ...      ...
# 312516               0            1                            []       []
# 312517               1           12                   ['bitcoin']       []
# 312518               2            8                            []       []
# 312519               4            7                            []       []
# 312520               3            9                   ['bitcoin']       []
#
#                                                      link  \
# 0       https://twitter.com/dumbfoundead/status/121223...
# 1       https://twitter.com/neuroecology/status/121225...
# 2       https://twitter.com/CNBCTV18News/status/121226...
# 3       https://twitter.com/Excellion/status/121227194...
# 4       https://twitter.com/HindustanTimes/status/1212...
# ...                                                   ...
# 312516  https://twitter.com/AdeldMeyer/status/14771325...
# 312517  https://twitter.com/jaygould/status/1477134677...
# 312518  https://twitter.com/nvk/status/147713702889467...
# 312519  https://twitter.com/staronline/status/14771383...
# 312520  https://twitter.com/LordFusitua/status/1477141...
#
#                                                 quote_url  video  \
# 0                                                    <NA>  False
# 1                                                    <NA>  False
# 2                                                    <NA>  False
# 3                                                    <NA>   True
# 4                                                    <NA>  False
# ...                                                   ...    ...
# 312516                                               <NA>  False
# 312517                                               <NA>   True
# 312518                                               <NA>  False
# 312519                                               <NA>  False
# 312520  https://twitter.com/1ARMPUSHUPKING/status/1477...  False
#
#                                               thumbnail  \
# 0                                                  <NA>
# 1                                                  <NA>
# 2                                                  <NA>
# 3       https://pbs.twimg.com/media/ENLa5toU0AAvhC1.jpg
# 4                                                  <NA>
# ...                                                 ...
# 312516                                             <NA>
# 312517  https://pbs.twimg.com/media/FH_WKPYXsAQRYg_.jpg
# 312518                                             <NA>
# 312519                                             <NA>
# 312520                                             <NA>
#
#                                                  reply_to
# 0                                                      []
# 1                                                      []
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 312516  [{'screen_name': 'Bitcoin__art', 'name': 'bitc...
# 312517                                                 []
# 312518  [{'screen_name': 'rubiconcapital_', 'name': 'K...
# 312519                                                 []
# 312520                                                 []
#
# [312521 rows x 21 columns]
