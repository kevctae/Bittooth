# %%
# imports

import re
import spacy
import en_core_web_sm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from IPython.core.interactiveshell import InteractiveShell
from tqdm.notebook import tqdm
from scipy.ndimage import gaussian_filter1d

# %%
# import configurations

sp = spacy.load('en_core_web_sm')
nlp = en_core_web_sm.load()
InteractiveShell.ast_node_interactivity = "all"
tqdm.pandas()

# %%
# read file

df = pd.read_pickle("../data/cleaned/tweets_verified_2020-2021_cleaned.pkl")
display(df.head())
# Out:
#                  created_at                   id      conversation_id  \
# 0 2020-01-01 00:08:28-05:00  1212239143687741440  1212239143687741440
# 1 2020-01-01 00:54:35-05:00  1212250748815208448  1212250748815208448
# 2 2020-01-01 02:00:25-05:00  1212267316789952512  1212267316789952512
# 3 2020-01-01 02:18:48-05:00  1212271940502638593  1212271940502638593
# 4 2020-01-01 02:54:22-05:00  1212280892103770114  1212280892103770114
#
#      user_id      username              name  \
# 0   20646945  dumbfoundead  dumbfoundead.eth
# 1  636023721  neuroecology    Adam J Calhoun
# 2  631810714  cnbctv18news         CNBC-TV18
# 3   14654494     excellion        Samson Mow
# 4     918711  ourielohayon             OOeb3
#
#                                                tweet language  \
# 0      Bitcoin the worst decision i made this decade       en
# 1  If you ask someone what they'd do if they went...       en
# 2  #bitcoin rally begun in 2013 and it reached a ...       en
# 3  Wishing all #Bitcoin Ultra Enthusiasts a very ...       en
# 4  2020  predictions  Bitcoin will crash to sub-1...       en
#
#                                             mentions  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3  [{'screen_name': 'blockstream', 'name': 'block...
# 4                                                 []
#
#                                                 urls  ... retweets_count  \
# 0                                                 []  ...             15
# 1                                                 []  ...              0
# 2  ['https://www.cnbctv18.com/market/currency/bit...  ...              0
# 3                                                 []  ...             17
# 4                                                 []  ...             12
#
#    likes_count                      hashtags  cashtags  \
# 0          409                            []        []
# 1            4                            []        []
# 2            4                   ['bitcoin']        []
# 3          158  ['bitcoin', 'liquidnetwork']        []
# 4           33                            []        []
#
#                                                 link quote_url  video  \
# 0  https://twitter.com/dumbfoundead/status/121223...      <NA>  False
# 1  https://twitter.com/neuroecology/status/121225...      <NA>  False
# 2  https://twitter.com/CNBCTV18News/status/121226...      <NA>  False
# 3  https://twitter.com/Excellion/status/121227194...      <NA>   True
# 4  https://twitter.com/OurielOhayon/status/121228...      <NA>  False
#
#                                          thumbnail  reply_to  \
# 0                                             <NA>        []
# 1                                             <NA>        []
# 2                                             <NA>        []
# 3  https://pbs.twimg.com/media/ENLa5toU0AAvhC1.jpg        []
# 4                                             <NA>        []
#
#                                          tweet_clean
# 0                         worst decision made decade
# 1  ask someone went back ten years use informatio...
# 2                           rally begun reached peak
# 3  wishing ultra enthusiasts happy new year much ...
# 4  predictions crash sub usd hardware wallets hac...
#
# [5 rows x 22 columns]

# %%
sent_obj = SentimentIntensityAnalyzer()
sent_data = df['tweet']

pest_words = {
    'up': 2.0,
    'down': -2.0,
    'green' : 2.0,
    'red' : -2.0,
    'bull' : 2.0,
    'bear' : -2.0,
    'buy' : 2.0,
    'bought' : 2.0,
    'sell' : -2.0,
    'sold' : -2.0,
    'moon': 2
}

new_si = SentimentIntensityAnalyzer()
new_si.lexicon.update(pest_words)

sentiment_update = []
for i in tqdm(sent_data):
    sentiment_update.append(sent_obj.polarity_scores(i))
# Out:
#   0%|          | 0/253613 [00:00<?, ?it/s]

# %%
sentiment_update[:4]
display(len(sentiment_update))
# Out:
# [{'neg': 0.369, 'neu': 0.631, 'pos': 0.0, 'compound': -0.6249},
#  {'neg': 0.0, 'neu': 0.936, 'pos': 0.064, 'compound': 0.4329},
#  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'compound': 0.1027},
#  {'neg': 0.0, 'neu': 0.705, 'pos': 0.295, 'compound': 0.9482}]
# 253613

# %%
all_compound = [one_tok['compound'] for one_tok in sentiment_update]
df['sentiment'] = pd.DataFrame(all_compound)
display(df[['tweet_clean', 'sentiment']])
df[df.tweet.str.contains('https://t.co/iuYO9oolUI')]
# Out:
#                                               tweet_clean  sentiment
# 0                              worst decision made decade    -0.6249
# 1       ask someone went back ten years use informatio...     0.4329
# 2                                rally begun reached peak     0.1027
# 3       wishing ultra enthusiasts happy new year much ...     0.9482
# 4       predictions crash sub usd hardware wallets hac...    -0.3197
# ...                                                   ...        ...
# 253608  husband stored bank accounts secret girlfriend...    -0.2960
# 253609                                        fair enough     0.8316
# 253610                                     happy new year     0.5719
# 253611           buy amp chill defund political parasites     0.0000
# 253612               great example fellow familia brother     0.4019
#
# [253613 rows x 2 columns]
#                    created_at                   id      conversation_id  \
# 249 2020-01-03 08:12:40-05:00  1213085771567108097  1213084317372563456
#
#         user_id      username            name  \
# 249  2933805082  fintechfrank  Frank Chaparro
#
#                                                  tweet language mentions urls  \
# 249  Bitcoin up 2.58% over the last 24 hours  https...       en       []   []
#
#      ... likes_count  hashtags  cashtags  \
# 249  ...           7        []        []
#
#                                                   link quote_url video  \
# 249  https://twitter.com/fintechfrank/status/121308...      <NA>  True
#
#                                            thumbnail reply_to    tweet_clean  \
# 249  https://pbs.twimg.com/media/ENW_EWBXsAAQ3Yp.png       []  up last hours
#
#     sentiment
# 249       0.0
#
# [1 rows x 23 columns]

# %%
# export as pickle
df[['id', 'sentiment']].to_pickle("../data/cleaned/by_id_verified_sentiment_2020-2021.pkl")

# %%
# try reading pickle
df_test = pd.read_pickle("../data/cleaned/by_id_verified_sentiment_2020-2021.pkl")

display(df_test.dtypes)
display(df_test)
# Out:
# id             int64
# sentiment    float64
# dtype: object
#                          id  sentiment
# 0       1212239143687741440    -0.6249
# 1       1212250748815208448     0.4329
# 2       1212267316789952512     0.1027
# 3       1212271940502638593     0.9482
# 4       1212280892103770114    -0.3197
# ...                     ...        ...
# 253608  1477129847482855425    -0.2960
# 253609  1477132523826147330     0.8316
# 253610  1477134677148323841     0.5719
# 253611  1477137028894670855     0.0000
# 253612  1477141468921794560     0.4019
#
# [253613 rows x 2 columns]
